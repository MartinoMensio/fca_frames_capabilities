# %%
from concepts import Context

# %%
# create a formal context: load a Markdown string or from CTX or CSV
c = Context.fromstring('''
           |human|knight|king |mysterious|
King Arthur|  X  |  X   |  X  |          |
Sir Robin  |  X  |  X   |     |          |
holy grail |     |      |     |     X    |
''')

# %%
# query common properties from objects
c.intension(['King Arthur', 'Sir Robin'])
# Out:
# ('human', 'knight')

# %%
# query common objects from properties
c.extension(['knight', 'mysterious'])
# Out:
# ()

# %%
# get closest matching objects-properies pairs
c['Sir Robin', 'holy grail']
# Out:
# (('King Arthur', 'Sir Robin', 'holy grail'), ())

# %%
c['king',]
# Out:
# (('King Arthur',), ('human', 'knight', 'king'))

# %%
c.lattice.graphviz()
