# %%
from conceptnet import ConceptNet
wrapper = ConceptNet()
word = 'Book'
word_id = wrapper.getId(word)
# follow triples [current_words], IsA, ?
results = wrapper.get_hypernyms(word_id)
# Out:
# ohi
# %%
# not explored  1 / 1568
# ...

# %%
# that's crazy, and only from wordnet
len(results)
# Out:
# 1568
